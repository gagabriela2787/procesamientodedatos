# %% [markdown]
# <a href="https://colab.research.google.com/github/gagabriela2787/procesamientodedatos/blob/main/clase55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar bibliotecas necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar archivos CSV
#enlace https://www.kaggle.com/datasets/tinnqn/precios-claros-precios-de-argentina
precios_df = pd.read_csv('precios_20200412_20200413.csv')
productos_df = pd.read_csv('productos.csv')
sucursales_df = pd.read_csv('sucursales.csv')

# Unir DataFrames por clave principal
productos_precios_df = pd.merge(precios_df, productos_df, left_on='producto_id', right_on='id')
sucursales_productos_precios_df = pd.merge(productos_precios_df, sucursales_df, left_on='sucursal_id', right_on='id')

# Eliminar columnas innecesarias
sucursales_productos_precios_df.drop(['id_x', 'id_y'], axis=1, inplace=True)

# Mostrar las primeras filas del DataFrame resultante
print(sucursales_productos_precios_df.head())

# Estadísticas descriptivas del DataFrame resultante
print(sucursales_productos_precios_df.describe())

# Gráfico de barras de los precios por sucursal
sns.barplot(x='sucursalNombre', y='precio', data=sucursales_productos_precios_df)
plt.title('Precios por sucursal')
plt.xlabel('Sucursal')
plt.ylabel('Precio')
plt.show()

# Gráfico de dispersión de los precios por provincia
sns.scatterplot(x='provincia', y='precio', data=sucursales_productos_precios_df)
plt.title('Precios por provincia')
plt.xlabel('Provincia')
plt.ylabel('Precio')
plt.show()

#consulta de precios hasta 30000
productos_precios_df[productos_precios_df['precio'] > 30000]
# Out:
#    precio    producto_id sucursal_id       marca  \
# 0    29.9  0000000001663     2-1-014  LA ANÓNIMA
# 1   181.0  0000075024956     2-1-014      REXONA
# 2   181.0  0000075026455     2-1-014      REXONA
# 3   216.0  0000075027513     2-1-014        DOVE
# 4    87.0  0000077900050     2-1-014      ILOLAY
#
#                                               nombre presentacion categoria1  \
# 0                    Radicheta Atada La Anonima 1 Un       1.0 un        NaN
# 1  Desodorante Antitranspirante en Barra Men V8 R...      50.0 gr        NaN
# 2           Desodorante Stick Nutritivo Rexona 50 Gr      50.0 gr        NaN
# 3                    Desodorante Original Dove 50 Gr      50.0 gr        NaN
# 4                              Manteca Ilolay 100 Gr     100.0 gr        NaN
#
#   categoria2 categoria3  comercioId  banderaId banderaDescripcion  \
# 0        NaN        NaN           2          1         La Anonima
# 1        NaN        NaN           2          1         La Anonima
# 2        NaN        NaN           2          1         La Anonima
# 3        NaN        NaN           2          1         La Anonima
# 4        NaN        NaN           2          1         La Anonima
#
#                               comercioRazonSocial provincia      localidad  \
# 0  S.A. Importadora y Exportadora de la Patagonia      AR-U  Puerto Madryn
# 1  S.A. Importadora y Exportadora de la Patagonia      AR-U  Puerto Madryn
# 2  S.A. Importadora y Exportadora de la Patagonia      AR-U  Puerto Madryn
# 3  S.A. Importadora y Exportadora de la Patagonia      AR-U  Puerto Madryn
# 4  S.A. Importadora y Exportadora de la Patagonia      AR-U  Puerto Madryn
#
#        direccion       lat       lng sucursalNombre  sucursalTipo
# 0  H.Yrigoyen 76 -42.76422 -65.03623  PUERTO MADRYN  Supermercado
# 1  H.Yrigoyen 76 -42.76422 -65.03623  PUERTO MADRYN  Supermercado
# 2  H.Yrigoyen 76 -42.76422 -65.03623  PUERTO MADRYN  Supermercado
# 3  H.Yrigoyen 76 -42.76422 -65.03623  PUERTO MADRYN  Supermercado
# 4  H.Yrigoyen 76 -42.76422 -65.03623  PUERTO MADRYN  Supermercado
#               precio     comercioId      banderaId            lat  \
# count  467993.000000  467993.000000  467993.000000  467993.000000
# mean      184.071171      16.240510       1.693410     -34.690655
# std       355.197640      13.672629       1.182509       5.778477
# min         0.120000       2.000000       1.000000     -54.810100
# 25%        65.970000       9.000000       1.000000     -35.444167
# 50%       117.700000      10.000000       1.000000     -34.602117
# 75%       211.000000      16.000000       2.000000     -32.423605
# max     34417.150000      50.000000       6.000000     -23.135733
#
#                  lng
# count  467993.000000
# mean      -62.622100
# std         4.098240
# min       -71.348518
# 25%       -65.778434
# 50%       -61.895790
# 75%       -58.575528
# max       -55.909301
#          precio    producto_id sucursal_id             id           marca  \
# 22045  30528.00  3049614158322    12-1-185  3049614158322  LA GRANDE DAME
# 22336  32860.00  3185370611746    12-1-185  3185370611746    DOM PERIGNON
# 22337  31000.00  3185370611746    12-1-209  3185370611746    DOM PERIGNON
# 30971  34417.15  5000299284926    12-1-185  5000299284926    CHIVAS REGAL
# 30972  32469.00  5000299284926    12-1-209  5000299284926    CHIVAS REGAL
#
#                                                 nombre presentacion  \
# 22045  Champagne en Estuche La Grande Dame Rose 750 Cc     750.0 cc
# 22336  Champagne Rose Estuche Dom Perignon 750 Cc 1 Un     750.0 cc
# 22337  Champagne Rose Estuche Dom Perignon 750 Cc 1 Un     750.0 cc
# 30971              Whisky 25 Años Chivas Regal 700 Ml     700.0 ml
# 30972              Whisky 25 Años Chivas Regal 700 Ml     700.0 ml
#
#       categoria1 categoria2 categoria3
# 22045        NaN        NaN        NaN
# 22336        NaN        NaN        NaN
# 22337        NaN        NaN        NaN
# 30971        NaN        NaN        NaN
# 30972        NaN        NaN        NaN
